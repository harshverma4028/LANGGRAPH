# %%
from langgraph.graph import StateGraph, START, END
from langchain_anthropic import ChatAnthropic
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
model = ChatAnthropic(model='claude-3-5-sonnet-20241022')

# %%
class BlogState(TypedDict):

    title : str
    outline: str
    content: str
    score: int

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # Update state
    state['outline'] = outline

    return state

# %%
def evaluate(state: BlogState) -> BlogState:

    outline = state['outline']
    content = state['content']

    prompt = f'based on the outline - {outline} rate my following blog \n{content}  between 1 to 10 '
    score = model.invoke(prompt).content

    state['score'] = score

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']
    outline = state['outline']

    # call llm gen outline
    prompt = f'write a detailed blog on the title - {title} using the following outline \n {outline}'
    content = model.invoke(prompt).content

    # Update state
    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline',create_outline)
graph.add_node('create_blog',create_blog)
graph.add_node('evaluate',evaluate)

# EDge
graph.add_edge(START,'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog','evaluate')
graph.add_edge('evaluate',END)

workflow = graph.compile()

# %%
initial_state = {'title':'Rise of AI in India'}

final_state = workflow.invoke(initial_state)

print(final_state['content'])
# Out:
# The Rise of AI in India: Transforming the Digital Landscape
#
# Introduction:
# Artificial Intelligence (AI) has emerged as a transformative force in the global technological landscape, and India stands at the forefront of this revolution. With its vast talent pool, growing digital infrastructure, and supportive government policies, India is rapidly becoming a significant player in the global AI ecosystem. Recent statistics show that India's AI market is expected to reach $7.8 billion by 2025, growing at a CAGR of 20.2%.
#
# Current State of AI in India:
# The AI landscape in India is witnessing unprecedented growth across multiple sectors. The market size has already reached $3.1 billion in 2022, with key sectors leading the adoption. In IT and Technology, companies are leveraging AI for process automation and enhanced customer service. Healthcare has seen revolutionary applications in diagnostics and patient care, while the banking sector is utilizing AI for fraud detection and personalized services. Manufacturing industries are implementing AI for predictive maintenance and quality control, and agriculture is benefiting from AI-powered crop monitoring and yield prediction systems.
#
# The government's initiatives like the National AI Strategy and Digital India have created a conducive environment for AI growth. The Make in India program has further accelerated AI adoption in manufacturing and innovation.
#
# AI Ecosystem in India:
# India's AI startup ecosystem is thriving, with over 2,000 AI startups as of 2023. Notable success stories include companies like Fractal Analytics and MuSigma, which have achieved unicorn status. The country has also attracted significant investments, with AI startups raising over $836.3 million in 2022 alone.
#
# Research and development efforts are strengthened by premier institutions like IITs and IISc, which have established dedicated AI research centers. Tech giants like Google, Microsoft, and IBM have set up AI research facilities in India, while Indian IT majors like TCS and Infosys are developing innovative AI solutions.
#
# Workforce and Skills:
# India produces approximately 2.5 million STEM graduates annually, creating a robust talent pipeline for AI development. However, a significant skills gap exists, with only 30% of AI professionals having relevant expertise. Various initiatives by both government and private sectors are addressing this through specialized training programs and industry-academia partnerships.
#
# Applications and Success Stories:
# The healthcare sector has seen remarkable AI applications, from early disease detection to telemedicine solutions. Financial services have transformed with AI-powered chatbots and risk assessment tools. Agricultural innovations include crop disease detection and smart irrigation systems. Smart cities are implementing AI for traffic management and urban planning.
#
# Challenges and Barriers:
# Despite the progress, India faces several challenges. Infrastructure limitations, particularly in tier-2 and tier-3 cities, pose significant hurdles. Data privacy concerns and the need for robust regulatory frameworks remain critical issues. The digital divide between urban and rural areas continues to be a challenge, along with the need for increased investment in AI research and development.
#
# Future Prospects:
# The future of AI in India looks promising, with projections suggesting the AI industry could contribute $957 billion to India's economy by 2035. Emerging opportunities in sectors like education, retail, and logistics present new avenues for growth. India's potential to become a global AI hub is reinforced by its large talent pool and growing technological capabilities.
#
# Impact on Society:
# The rise of AI is expected to create 3.0 million jobs in India by 2025, though it may also displace certain traditional roles. The economic impact includes increased productivity and efficiency across sectors. Social implications range from improved healthcare access to enhanced educational opportunities.
#
# Recommendations:
# To fully realize AI's potential, India needs:
# - Strengthened data protection laws
# - Enhanced digital infrastructure
# - Focused skill development programs
# - Increased industry-academia collaboration
# - Strategic international partnerships
#
# Conclusion:
# India's journey in AI is at a crucial juncture, with immense potential for growth and innovation. With continued focus on addressing challenges and leveraging strengths, India is well-positioned to become a global AI powerhouse. The success of this transformation will depend on collaborative efforts from government, industry, and academia.
#
# Additional Resources:
# - NITI Aayog's National Strategy for AI
# - Ministry of Electronics and IT (MeitY) guidelines
# - AI research publications from Indian institutions
# - Industry reports from NASSCOM and other organizations
#
# This comprehensive overview demonstrates India's significant progress in AI adoption while highlighting areas requiring attention for sustained growth and development.

# %%
print(final_state['score'])
# Out:
# I would rate this blog an 8.5/10. Here's why:
#
# Strengths (What makes it great):
# 1. Well-structured and follows the outline precisely
# 2. Rich in current data and statistics
# 3. Comprehensive coverage of all major aspects
# 4. Clear and professional writing style
# 5. Good balance between technical information and readability
# 6. Includes specific examples and success stories
# 7. Provides actionable recommendations
# 8. Incorporates relevant current market figures
#
# Areas for Improvement:
# 1. Could include more specific case studies or real-world examples
# 2. The "Impact on Society" section could be more detailed
# 3. More discussion on ethical considerations and AI governance
# 4. Could benefit from more comparative analysis with other countries
# 5. Additional visual elements (graphs, charts) would enhance engagement
#
# The blog effectively captures the essence of AI's rise in India while maintaining reader interest through relevant information and logical flow. It's informative enough for professionals while remaining accessible to general readers interested in AI developments in India.
#
# To make it a perfect 10, consider adding:
# - More specific success stories
# - Comparative analysis with global AI leaders
# - Deeper discussion of ethical implications
# - Visual data representation
# - More detailed future scenarios
#
# Overall, it's a strong piece that serves its purpose well and provides valuable insights into India's AI landscape.

# %%
print(final_state['outline'])
# Out:
# Here's a detailed outline for a blog on "Rise of AI in India":
#
# I. Introduction
#    A. Brief overview of AI's global impact
#    B. India's emerging role in the AI revolution
#    C. Statistics on AI adoption in India
#
# II. Current State of AI in India
#     A. Market size and growth projections
#     B. Key sectors implementing AI
#        1. IT and Technology
#        2. Healthcare
#        3. Finance and Banking
#        4. Manufacturing
#        5. Agriculture
#     C. Government initiatives and policies
#        1. National AI Strategy
#        2. Digital India
#        3. Make in India
#
# III. AI Ecosystem in India
#      A. Startup landscape
#         1. Major AI startups
#         2. Funding scenarios
#         3. Success stories
#      B. Research and Development
#         1. Academic institutions
#         2. Research centers
#         3. Industry-academia partnerships
#      C. Tech giants' AI operations in India
#         1. Google
#         2. Microsoft
#         3. IBM
#         4. Indian tech companies (TCS, Infosys, etc.)
#
# IV. Workforce and Skills
#     A. AI talent pool in India
#     B. Skills gap and challenges
#     C. Training and education initiatives
#     D. Job market trends
#
# V. Applications and Success Stories
#    A. Healthcare innovations
#    B. Financial services transformation
#    C. Agricultural solutions
#    D. Smart cities implementation
#    E. Education sector applications
#
# VI. Challenges and Barriers
#     A. Infrastructure limitations
#     B. Data privacy concerns
#     C. Digital divide
#     D. Regulatory framework
#     E. Investment constraints
#
# VII. Future Prospects
#      A. Growth predictions
#      B. Emerging opportunities
#         1. New sectors
#         2. Job creation
#         3. Economic impact
#      C. Potential areas for development
#      D. Global competitiveness
#
# VIII. Impact on Society
#       A. Employment implications
#       B. Economic effects
#       C. Social changes
#       D. Ethical considerations
#
# IX. Recommendations
#     A. Policy suggestions
#     B. Infrastructure development
#     C. Education and training
#     D. Industry collaboration
#     E. International partnerships
#
# X. Conclusion
#    A. Summary of key points
#    B. India's potential as an AI powerhouse
#    C. Call to action for stakeholders
#
# XI. Additional Resources
#     A. References
#     B. Further reading
#     C. Useful links
#     D. Industry contacts
#
# This outline covers comprehensive aspects of AI's rise in India, from current developments to future prospects, making it suitable for a detailed blog post. The structure allows for both breadth and depth in covering the topic while maintaining a logical flow of information.

# %%
print(final_state['content'])
# Out:
# The Rise of AI in India: Transforming the Digital Landscape
#
# Introduction:
# Artificial Intelligence (AI) has emerged as a transformative force in the global technological landscape, and India stands at the forefront of this revolution. With its vast talent pool, growing digital infrastructure, and supportive government policies, India is rapidly becoming a significant player in the global AI ecosystem. Recent statistics show that India's AI market is expected to reach $7.8 billion by 2025, growing at a CAGR of 20.2%.
#
# Current State of AI in India:
# The AI landscape in India is witnessing unprecedented growth across multiple sectors. The market size has already reached $3.1 billion in 2022, with key sectors leading the adoption. In IT and Technology, companies are leveraging AI for process automation and enhanced customer service. Healthcare has seen revolutionary applications in diagnostics and patient care, while the banking sector is utilizing AI for fraud detection and personalized services. Manufacturing industries are implementing AI for predictive maintenance and quality control, and agriculture is benefiting from AI-powered crop monitoring and yield prediction systems.
#
# The government's initiatives like the National AI Strategy and Digital India have created a conducive environment for AI growth. The Make in India program has further accelerated AI adoption in manufacturing and innovation.
#
# AI Ecosystem in India:
# India's AI startup ecosystem is thriving, with over 2,000 AI startups as of 2023. Notable success stories include companies like Fractal Analytics and MuSigma, which have achieved unicorn status. The country has also attracted significant investments, with AI startups raising over $836.3 million in 2022 alone.
#
# Research and development efforts are strengthened by premier institutions like IITs and IISc, which have established dedicated AI research centers. Tech giants like Google, Microsoft, and IBM have set up AI research facilities in India, while Indian IT majors like TCS and Infosys are developing innovative AI solutions.
#
# Workforce and Skills:
# India produces approximately 2.5 million STEM graduates annually, creating a robust talent pipeline for AI development. However, a significant skills gap exists, with only 30% of AI professionals having relevant expertise. Various initiatives by both government and private sectors are addressing this through specialized training programs and industry-academia partnerships.
#
# Applications and Success Stories:
# The healthcare sector has seen remarkable AI applications, from early disease detection to telemedicine solutions. Financial services have transformed with AI-powered chatbots and risk assessment tools. Agricultural innovations include crop disease detection and smart irrigation systems. Smart cities are implementing AI for traffic management and urban planning.
#
# Challenges and Barriers:
# Despite the progress, India faces several challenges. Infrastructure limitations, particularly in tier-2 and tier-3 cities, pose significant hurdles. Data privacy concerns and the need for robust regulatory frameworks remain critical issues. The digital divide between urban and rural areas continues to be a challenge, along with the need for increased investment in AI research and development.
#
# Future Prospects:
# The future of AI in India looks promising, with projections suggesting the AI industry could contribute $957 billion to India's economy by 2035. Emerging opportunities in sectors like education, retail, and logistics present new avenues for growth. India's potential to become a global AI hub is reinforced by its large talent pool and growing technological capabilities.
#
# Impact on Society:
# The rise of AI is expected to create 3.0 million jobs in India by 2025, though it may also displace certain traditional roles. The economic impact includes increased productivity and efficiency across sectors. Social implications range from improved healthcare access to enhanced educational opportunities.
#
# Recommendations:
# To fully realize AI's potential, India needs:
# - Strengthened data protection laws
# - Enhanced digital infrastructure
# - Focused skill development programs
# - Increased industry-academia collaboration
# - Strategic international partnerships
#
# Conclusion:
# India's journey in AI is at a crucial juncture, with immense potential for growth and innovation. With continued focus on addressing challenges and leveraging strengths, India is well-positioned to become a global AI powerhouse. The success of this transformation will depend on collaborative efforts from government, industry, and academia.
#
# Additional Resources:
# - NITI Aayog's National Strategy for AI
# - Ministry of Electronics and IT (MeitY) guidelines
# - AI research publications from Indian institutions
# - Industry reports from NASSCOM and other organizations
#
# This comprehensive overview demonstrates India's significant progress in AI adoption while highlighting areas requiring attention for sustained growth and development.
